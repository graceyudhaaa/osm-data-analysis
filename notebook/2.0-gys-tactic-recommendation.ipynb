# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/processed/osm_data.csv')
df.head()
# Out:
#   strength opponent_formation opponent_style_of_play opponent_marking
# 0     weak            4-3-3 b         shoot on sight    zonal marking  \
# 1   strong            4-2-3-1           passing game    zonal marking
# 2     weak            4-4-2 b         shoot on sight      man marking
# 3    equal            4-2-3-1           passing game    zonal marking
# 4     weak            4-2-3-1           passing game    zonal marking
#
#   opponent_offside_trap opponent_tackling opponent_training_camp formation
# 0                    no         aggresive                     no   4-2-3-1  \
# 1                    no            normal                     no   4-2-3-1
# 2                    no         aggresive                     no   4-2-3-1
# 3                    no            normal                     no   6-3-1 b
# 4                    no            normal                     no   6-3-1 b
#
#     style_of_play        marking  ... style tempo goals opponent_goals
# 0  shoot on sight    man marking  ...    46    39     3              0  \
# 1  shoot on sight    man marking  ...    46    39     1              0
# 2  shoot on sight    man marking  ...    46    39     1              0
# 3  counter-attack  zonal marking  ...    24    65     2              0
# 4  counter-attack  zonal marking  ...    25    66     1              0
#
#   goal_diff posession  opponent_posession  shots  opponent_shots  result
# 0         3        63                  37     11               3     won
# 1         1        61                  39      8               4     won
# 2         1        68                  32     10               3     won
# 3         2        58                  42      6               4     won
# 4         1        62                  38      8               3     won
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['strength', 'opponent_formation', 'opponent_style_of_play',
#        'opponent_marking', 'opponent_offside_trap', 'opponent_tackling',
#        'opponent_training_camp', 'formation', 'style_of_play', 'marking',
#        'offside_trap', 'tackling', 'training_camp', 'line_tactic_FW',
#        'line_tactic_MF', 'line_tactic_DF', 'pressing', 'style', 'tempo',
#        'goals', 'opponent_goals', 'goal_diff', 'posession',
#        'opponent_posession', 'shots', 'opponent_shots', 'result'],
#       dtype='object')

# %%
df[(df['strength'] == 'strong') & (df['opponent_formation'] == '4-2-3-1') & ((df['result'] == 'won'))]
# Out:
#     strength opponent_formation opponent_style_of_play opponent_marking
# 1     strong            4-2-3-1           passing game    zonal marking  \
# 19    strong            4-2-3-1         counter-attack    zonal marking
# 36    strong            4-2-3-1         shoot on sight    zonal marking
# 48    strong            4-2-3-1         shoot on sight    zonal marking
# 98    strong            4-2-3-1         counter-attack    zonal marking
# 113   strong            4-2-3-1         shoot on sight    zonal marking
# 119   strong            4-2-3-1              long ball    zonal marking
# 120   strong            4-2-3-1         shoot on sight    zonal marking
# 131   strong            4-2-3-1         shoot on sight    zonal marking
# 148   strong            4-2-3-1           passing game    zonal marking
#
#     opponent_offside_trap opponent_tackling opponent_training_camp formation
# 1                      no            normal                     no   4-2-3-1  \
# 19                     no         aggresive                     no     4-5-1
# 36                     no         aggresive                     no   6-3-1 b
# 48                     no         aggresive                     no   6-3-1 b
# 98                     no         aggresive                     no     4-5-1
# 113                    no         aggresive                     no     4-5-1
# 119                    no         aggresive                     no     4-5-1
# 120                    no         aggresive                     no     4-5-1
# 131                    no         aggresive                     no     4-5-1
# 148                    no            normal                     no     4-5-1
#
#       style_of_play        marking  ... style tempo goals opponent_goals
# 1    shoot on sight    man marking  ...    46    39     1              0  \
# 19   shoot on sight  zonal marking  ...    63    79     3              1
# 36   shoot on sight  zonal marking  ...    75    77     5              0
# 48   counter-attack  zonal marking  ...    62    76     1              0
# 98   shoot on sight  zonal marking  ...    63    79     5              0
# 113       wing play  zonal marking  ...    63    79     1              0
# 119  shoot on sight  zonal marking  ...    75    77     1              0
# 120       wing play  zonal marking  ...    63    79     3              0
# 131       wing play  zonal marking  ...    63    79     4              0
# 148       wing play  zonal marking  ...    63    79     3              0
#
#     goal_diff posession  opponent_posession  shots  opponent_shots  result
# 1           1        61                  39      8               4     won
# 19          2        66                  34     10               4     won
# 36          5        69                  31     11               3     won
# 48          1        61                  39      7               3     won
# 98          5        65                  35     12               1     won
# 113         1        61                  39     10               1     won
# 119         1        70                  30     14               2     won
# 120         3        63                  37     14               4     won
# 131         4        64                  36     13               3     won
# 148         3        63                  37     15               3     won
#
# [10 rows x 27 columns]

# %%
df[(df['strength'] == 'weak') & (df['formation'] == '4-2-3-1') & ((df['result'] == 'draw'))]
# Out:
#    strength opponent_formation opponent_style_of_play opponent_marking
# 72     weak            4-3-3 b         shoot on sight    zonal marking  \
#
#    opponent_offside_trap opponent_tackling opponent_training_camp formation
# 72                    no         aggresive                     no   4-2-3-1  \
#
#      style_of_play      marking  ... style tempo goals opponent_goals
# 72  shoot on sight  man marking  ...    46    39     1              1  \
#
#    goal_diff posession  opponent_posession  shots  opponent_shots  result
# 72         0        53                  47     11              10    draw
#
# [1 rows x 27 columns]

# %% [markdown]
# ## what formation that can counter opponent formation

# %% [markdown]
# create a function with an input: opponent formation
# return a recommendation of a formation that can counter opponent formation

# %%
# list of unique formation in the data
unique_formation = np.unique(np.hstack((np.array(df['formation']), np.array(df['opponent_formation']))))
unique_formation
# Out:
# array(['3-3-2-2', '3-3-4 a', '3-3-4 b', '3-4-3 a', '3-4-3 b', '3-5-2',
#        '4-2-3-1', '4-3-3 a', '4-3-3 b', '4-4-2 b', '4-5-1', '5-2-3 a',
#        '5-3-1-1', '5-3-2', '5-4-1 a', '6-3-1 b'], dtype=object)

# %%
# 
formation_dict = {}
for i in df[['strength', 'formation', 'opponent_formation', 'result']].iterrows():
    row = i[1] 

    # if we won, record opponent formation and save our formation as the counter
    if row['result'] == 'won':
        d = formation_dict.get(row['opponent_formation'], # top tier variable naming
                                    {'weak':[],
                                    'strong':[],
                                    'equal':[]})
        
        if row['formation'] not in d[row['strength']]:
            d[row['strength']].append(row['formation'])

        formation_dict[row['opponent_formation']] = d
    # if we lost, record our formation and save opponent formation as the counter
    elif row['result'] == 'lost':
        d = formation_dict.get(row['formation'],
                                    {'weak':[],
                                    'strong':[],
                                    'equal':[]})
        
        # swap 'weak' and 'strong' strength as we are saving opponent formation as a counter 
        if row['strength'] == 'equal':
            strength = 'equal'
        else:
            strength = 'weak' if row['strength'] == 'strong' else 'strong'

        if row['opponent_formation'] not in d[strength]:
            d[strength].append(row['opponent_formation'])

        formation_dict[row['formation']] = d

formation_dict
# Out:
# {'4-3-3 b': {'weak': ['4-2-3-1'],
#   'strong': ['4-3-3 a', '4-4-2 b'],
#   'equal': []},
#  '4-2-3-1': {'weak': ['6-3-1 b'],
#   'strong': ['4-2-3-1', '4-5-1', '4-4-2 b', '6-3-1 b'],
#   'equal': ['6-3-1 b']},
#  '4-4-2 b': {'weak': ['4-2-3-1', '4-3-3 b'],
#   'strong': ['4-3-3 b', '4-3-3 a'],
#   'equal': ['4-3-3 b']},
#  '3-3-4 a': {'weak': ['4-3-3 b'],
#   'strong': ['4-3-3 b', '3-3-4 a', '3-3-4 b', '4-3-3 a'],
#   'equal': []},
#  '3-3-2-2': {'weak': [], 'strong': ['4-4-2 b'], 'equal': ['4-4-2 b']},
#  '3-4-3 a': {'weak': ['3-5-2'], 'strong': ['3-5-2'], 'equal': []},
#  '4-3-3 a': {'weak': ['4-5-1'], 'strong': ['4-3-3 b'], 'equal': []},
#  '4-5-1': {'weak': [],
#   'strong': ['4-3-3 b', '4-3-3 a', '4-2-3-1'],
#   'equal': []},
#  '5-3-1-1': {'weak': [], 'strong': ['4-4-2 b'], 'equal': []},
#  '5-2-3 a': {'weak': [], 'strong': ['4-4-2 b'], 'equal': []},
#  '5-4-1 a': {'weak': [], 'strong': ['4-4-2 b'], 'equal': []},
#  '5-3-2': {'weak': [], 'strong': ['4-3-3 a'], 'equal': []}}

# %%
for formation in unique_formation:
    try:
        print(f'{formation}: {formation_dict[formation]}')
    except:
        print(f'{formation}: no data in formation_dict')
# Out:
# 3-3-2-2: {'weak': [], 'strong': ['4-4-2 b'], 'equal': ['4-4-2 b']}
# 3-3-4 a: {'weak': ['4-3-3 b'], 'strong': ['4-3-3 b', '3-3-4 a', '3-3-4 b', '4-3-3 a'], 'equal': []}
# 3-3-4 b: no data in formation_dict
# 3-4-3 a: {'weak': ['3-5-2'], 'strong': ['3-5-2'], 'equal': []}
# 3-4-3 b: no data in formation_dict
# 3-5-2: no data in formation_dict
# 4-2-3-1: {'weak': ['6-3-1 b'], 'strong': ['4-2-3-1', '4-5-1', '4-4-2 b', '6-3-1 b'], 'equal': ['6-3-1 b']}
# 4-3-3 a: {'weak': ['4-5-1'], 'strong': ['4-3-3 b'], 'equal': []}
# 4-3-3 b: {'weak': ['4-2-3-1'], 'strong': ['4-3-3 a', '4-4-2 b'], 'equal': []}
# 4-4-2 b: {'weak': ['4-2-3-1', '4-3-3 b'], 'strong': ['4-3-3 b', '4-3-3 a'], 'equal': ['4-3-3 b']}
# 4-5-1: {'weak': [], 'strong': ['4-3-3 b', '4-3-3 a', '4-2-3-1'], 'equal': []}
# 5-2-3 a: {'weak': [], 'strong': ['4-4-2 b'], 'equal': []}
# 5-3-1-1: {'weak': [], 'strong': ['4-4-2 b'], 'equal': []}
# 5-3-2: {'weak': [], 'strong': ['4-3-3 a'], 'equal': []}
# 5-4-1 a: {'weak': [], 'strong': ['4-4-2 b'], 'equal': []}
# 6-3-1 b: no data in formation_dict
